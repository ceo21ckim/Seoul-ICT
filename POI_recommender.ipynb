# %%
import glob

from settings import * 
from utils import * 

from sklearn.cluster import KMeans  

from folium import plugins

import matplotlib.pyplot as plt

# %%
file = glob.glob(os.path.join(DATA_DIR, '*'))[0]
dataframe = get_dataframe(file)
# Out:
# c:\Users\EonKim\OneDrive\02.project\관광데이터\utils.py:102: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   tour.loc[:, 'category'] = tour.loc[:, 'category'].apply(LabelEncoder)
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
m = plot_map(dataframe, save=False)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9dd4b851341c4e26b96f5eedbdafdddf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9dd4b851341c4e26b96f5eedbdafdddf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9dd4b851341c4e26b96f5eedbdafdddf = L.map(
#                 &quot;map_9dd4b851341c4e26b96f5eedbdafdddf&quot;,
#                 {
#                     center: [35.86953444232168, 128.59996652765759],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a0ef5f35d71d0eff319039350565fc06 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9dd4b851341c4e26b96f5eedbdafdddf);
#
#
#             var marker_ae4281c59b76772f4d7f6021e92a5d2c = L.marker(
#                 [35.8779406718693, 128.629190024219],
#                 {}
#             ).addTo(map_9dd4b851341c4e26b96f5eedbdafdddf);
#
#
#             var icon_4e5087b1ec19ade764a90f3411e0ee80 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bookmark&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ae4281c59b76772f4d7f6021e92a5d2c.setIcon(icon_4e5087b1ec19ade764a90f3411e0ee80);
#
#
#         var popup_62b36567fc046f6eed74fbddf8368691 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f654a48af0f4d7059825ddfba8adc3e3 = $(`&lt;div id=&quot;html_f654a48af0f4d7059825ddfba8adc3e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;신세계백화점대구점&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_62b36567fc046f6eed74fbddf8368691.setContent(html_f654a48af0f4d7059825ddfba8adc3e3);
#
#
#
#         marker_ae4281c59b76772f4d7f6021e92a5d2c.bindPopup(popup_62b36567fc046f6eed74fbddf8368691)
#         ;
#
#
#
#
#             var marker_79658f10dfd100fe10e6824beb2dd562 = L.marker(
#                 [35.8794361440597, 128.628775532684],
#                 {}
#             ).addTo(map_9dd4b851341c4e26b96f5eedbdafdddf);
#
#
#             var icon_654444648457f5151b898fc3baa03302 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bookmark&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_79658f10dfd100fe10e6824beb2dd562.setIcon(icon_654444648457f5151b898fc3baa03302);
#
#
#         var popup_e488f0d8882764e24af33acc2ec0a0be = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_001e74555d6599b1571bfee20bb84be8 = $(`&lt;div id=&quot;html_001e74555d6599b1571bfee20bb84be8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;동대구역&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_e488f0d8882764e24af33acc2ec0a0be.setContent(html_001e74555d6599b1571bfee20bb84be8);
#
#
#
#         marker_79658f10dfd100fe10e6824beb2dd562.bindPopup(popup_e488f0d8882764e24af33acc2ec0a0be)
#         ;
#
#
#
#
#             var marker_e5fa57463d8625860f5884ffa7c4c285 = L.marker(
#                 [35.8666296004242, 128.590625718585],
#                 {}
#             ).addTo(map_9dd4b851341c4e26b96f5eedbdafdddf);
#
#
#             var icon_a4c114ced31a15fd067bff34f92e279b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bookmark&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e5fa57463d8625860f5884ffa7c4c285.setIcon(icon_a4c114ced31a15fd067bff34f92e279b);
#
#
#         var popup_adb916ff30e18f54468603b35a95815a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c514f28ed000ac63e81665e5aa3e14f5 = $(`&lt;div id=&quot;html_c514f28ed000ac63e81665e5aa3e14f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;더현대대구&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_adb916ff30e18f54468603b35a95815a.setContent(html_c514f28ed000ac63e81665e5aa3e14f5);
#
#
#
#         marker_e5fa57463d8625860f5884ffa7c4c285.bindPopup(popup_adb916ff30e18f54468603b35a95815a)
#         ;
#
#
#
#
#             var marker_5be9251ff1e94c3738bf85cbf898a4f6 = L.marker(
#                 [35.8991086837334, 128.639261532187],
#                 {}
#             ).addTo(map_9dd4b851341c4e26b96f5eedbdafdddf);
#
#
#             var icon_ea4b0e43b0a7eee5d46d97b913a29e4b = L.Aweso

# %%
m = plot_cluster(dataframe)
m
# Out:
# c:\Users\EonKim\anaconda3\envs\torch\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cf5a0c7a50c29349d7605e3f29031f5f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cf5a0c7a50c29349d7605e3f29031f5f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cf5a0c7a50c29349d7605e3f29031f5f = L.map(
#                 &quot;map_cf5a0c7a50c29349d7605e3f29031f5f&quot;,
#                 {
#                     center: [35.86953444232168, 128.59996652765759],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ee9399f417ae28938bac59a6808792e5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cf5a0c7a50c29349d7605e3f29031f5f);
#
#
#             var circle_6ae2082dcb894b02baaffe58a5a0d0c8 = L.circle(
#                 [35.87518857138818, 128.62666718593147],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cf5a0c7a50c29349d7605e3f29031f5f);
#
#
#         var popup_0bd40ad398f7714b55cf11dffbcf05ae = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8df202fc22a4778a33405aa7fb04d872 = $(`&lt;div id=&quot;html_8df202fc22a4778a33405aa7fb04d872&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Center 0&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_0bd40ad398f7714b55cf11dffbcf05ae.setContent(html_8df202fc22a4778a33405aa7fb04d872);
#
#
#
#         circle_6ae2082dcb894b02baaffe58a5a0d0c8.bindPopup(popup_0bd40ad398f7714b55cf11dffbcf05ae)
#         ;
#
#
#
#
#             var circle_c554aa78a6bf6a92cace7e3322f394fc = L.circle(
#                 [35.83647553922866, 128.52804962662526],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cf5a0c7a50c29349d7605e3f29031f5f);
#
#
#         var popup_b372f2722c97717b47ee957df86b20e9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7de1c11de7850e304320c225562d3c87 = $(`&lt;div id=&quot;html_7de1c11de7850e304320c225562d3c87&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Center 1&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_b372f2722c97717b47ee957df86b20e9.setContent(html_7de1c11de7850e304320c225562d3c87);
#
#
#
#         circle_c554aa78a6bf6a92cace7e3322f394fc.bindPopup(popup_b372f2722c97717b47ee957df86b20e9)
#         ;
#
#
#
#
#             var circle_e9c554d76747c83b1005451eb6099047 = L.circle(
#                 [35.9955150088287, 128.6896995079462],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cf5a0c7a50c29349d7605e3f29031f5f);
#
#
#         var popup_23669c71595bfd7a7c06fefade3d0116 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d562d473173a5ff05cee6fc4c005ddec = $(`&lt;div id=&quot;html_d562d473173a5ff05cee6fc4c005ddec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Center 2&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_23669c71595bfd7a7c06fefade3d0116.setContent(html_d562d473173a5ff05cee6fc4c005ddec);
#
#
#
#         circle_e9c554d76747c83b1005451eb6099047.bindPopup(popup_23669c71595bfd7a7c06fefade3d0116)
#         ;
#
#
#
#
#             var marker_27102b01096a66903630bbd9290f6ff7 = L.marker(
#                 [35.8779406718693, 128.629190024219],
#                 {}
#             ).addTo(map_cf5a0c7a50c29349d7605e3f29031f5f);
#
#
#             var icon_
